# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
# The path to our CSV file
file = "AB_NYC_2019_clean.csv"

# Read file data into pandas
NYC_2019 = pd.read_csv(file)
NYC_2019.head()
# Out:
#    Unnamed: 0    id  host_id neighbourhood_group neighbourhood  latitude  \
# 0           0  2539     2787            Brooklyn    Kensington  40.64749
# 1           1  2595     2845           Manhattan       Midtown  40.75362
# 2           2  3647     4632           Manhattan        Harlem  40.80902
# 3           3  3831     4869            Brooklyn  Clinton Hill  40.68514
# 4           4  5022     7192           Manhattan   East Harlem  40.79851
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.97237     Private room    149               1                  9
# 1  -73.98377  Entire home/apt    225               1                 45
# 2  -73.94190     Private room    150               3                  0
# 3  -73.95976  Entire home/apt     89               1                270
# 4  -73.94399  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2               0.00                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
#descriptive data by neighbourhood 
mean = NYC_2019.groupby('neighbourhood')['number_of_reviews'].mean()
median = NYC_2019.groupby('neighbourhood')['number_of_reviews'].median()
variance = NYC_2019.groupby('neighbourhood')['number_of_reviews'].var()


summ_stats = pd.DataFrame ({"Mean Number of Reviews": mean, "Median Number of Reviews":median, 
                            "Number of Reviews":variance})
summ_stats
# Out:
#                  Mean Number of Reviews  Median Number of Reviews  \
# neighbourhood
# Allerton                      42.928571                      27.0
# Arden Heights                  7.750000                       5.0
# Arrochar                      14.619048                      11.0
# Arverne                       29.259740                      15.0
# Astoria                       21.455556                       5.0
# ...                                 ...                       ...
# Windsor Terrace               27.541401                       7.0
# Woodhaven                     31.727273                       8.0
# Woodlawn                      44.000000                       7.0
# Woodrow                        0.000000                       0.0
# Woodside                      21.425532                       3.0
#
#                  Number of Reviews
# neighbourhood
# Allerton               3765.531359
# Arden Heights            72.916667
# Arrochar                186.647619
# Arverne                1388.379016
# Astoria                1962.582005
# ...                            ...
# Windsor Terrace        1993.749878
# Woodhaven              3895.304075
# Woodlawn               4125.800000
# Woodrow                        NaN
# Woodside               2176.450627
#
# [221 rows x 3 columns]

# %%
#Groupby Burrough 
mean = NYC_2019.groupby('neighbourhood_group')['number_of_reviews'].mean()
median = NYC_2019.groupby('neighbourhood_group')['number_of_reviews'].median()
variance = NYC_2019.groupby('neighbourhood_group')['number_of_reviews'].var()


summ_stats2 = pd.DataFrame ({"Mean Number of Reviews": mean, "Median Number of Reviews":median, 
                            "Number of Reviews":variance})
summ_stats2
# Out:
#                      Mean Number of Reviews  Median Number of Reviews  \
# neighbourhood_group
# Bronx                             26.004583                         9
# Brooklyn                          24.202845                         6
# Manhattan                         20.985596                         4
# Queens                            27.700318                         7
# Staten Island                     30.941019                        12
#
#                      Number of Reviews
# neighbourhood_group
# Bronx                      1782.087135
# Brooklyn                   1966.467333
# Manhattan                  1812.398777
# Queens                     2699.410616
# Staten Island              2009.797587

# %%
# Generate a pie plot showing the distribution of neighbourhoods by bourough 
Hood_df=pd.DataFrame(NYC_2019.groupby(['neighbourhood_group']).count())
#Hood_df.head()
Hood_df.plot.pie(y='host_id', autopct='%1.1f%%',legend=False, shadow=True )
plt.title= ("Burrough Distribution")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
#Generate seperate Data frames of each burrough
brooklyn_df =NYC_2019.loc[(NYC_2019["neighbourhood_group"]== "Brooklyn")]
manhattan_df =NYC_2019.loc[(NYC_2019["neighbourhood_group"]== "Manhattan")]
queens_df =NYC_2019.loc[(NYC_2019["neighbourhood_group"]== "Queens")]
staten_df =NYC_2019.loc[(NYC_2019["neighbourhood_group"]== "Staten Island")]
bronx_df =NYC_2019.loc[(NYC_2019["neighbourhood_group"]== "Bronx")]
bronx_df.head()
# Out:
#      Unnamed: 0     id  host_id neighbourhood_group neighbourhood  latitude  \
# 171         171  44096   190409               Bronx    Highbridge  40.83232
# 207         207  54626   190409               Bronx    Highbridge  40.83075
# 260         260  63588   295128               Bronx  Clason Point  40.81309
# 261         261  63610   310670               Bronx   Eastchester  40.88057
# 309         309  71812   369015               Bronx   Kingsbridge  40.87207
#
#      longitude        room_type  price  minimum_nights  number_of_reviews  \
# 171  -73.93184     Private room     40               1                219
# 207  -73.93058     Private room     45               1                138
# 260  -73.85514     Private room     90               2                  0
# 261  -73.83572  Entire home/apt    105               2                 38
# 309  -73.90193  Entire home/apt     90              30                  4
#
#      reviews_per_month  calculated_host_listings_count  availability_365
# 171               2.04                               3               353
# 207               1.45                               3               323
# 260               0.00                               7               349
# 261               0.50                              13               365
# 309               0.35                               2               346

# %%
brooklyn_df.head()
# Out:
#     Unnamed: 0    id  host_id neighbourhood_group       neighbourhood  \
# 0            0  2539     2787            Brooklyn          Kensington
# 3            3  3831     4869            Brooklyn        Clinton Hill
# 6            6  5121     7356            Brooklyn  Bedford-Stuyvesant
# 12          12  5803     9744            Brooklyn         South Slope
# 15          15  6848    15991            Brooklyn        Williamsburg
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 0   40.64749  -73.97237     Private room    149               1
# 3   40.68514  -73.95976  Entire home/apt     89               1
# 6   40.68688  -73.95596     Private room     60              45
# 12  40.66829  -73.98779     Private room     89               4
# 15  40.70837  -73.95352  Entire home/apt    140               2
#
#     number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                   9               0.21                               6
# 3                 270               4.64                               1
# 6                  49               0.40                               1
# 12                167               1.34                               3
# 15                148               1.20                               1
#
#     availability_365
# 0                365
# 3                194
# 6                  0
# 12               314
# 15                46

# %%
brooklyn_df.plot.pie(y='host_id', autopct='%1.1f%%',legend=False, shadow=True )
plt.title= ("Brooklyn Neighbourhood Distribution")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
# Generate a bar plot showing the total number of reviews for all neighbourhoods for each bourough
pd_bar_plot= pd.DataFrame(brooklyn_df.groupby(['neighbourhood']).count()).reset_index()
pd_barplot = pd_bar_plot[["neighbourhood", 'number_of_reviews']]
pd_barplot.plot.bar(x='neighbourhood', title = 'Total Number of reviews per Neighbourhood- Brooklyn', legend = False)
plt.xlabel('Neighbourhood')
plt.ylabel("Measurements Taken")
