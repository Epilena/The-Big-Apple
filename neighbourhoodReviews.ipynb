# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats
import pandas as pd

# %%
#assign csv to variable
file_one = "AB_NYC_2019_clean.csv"

# %%
#Read in csv file
nh_df = pd.read_csv(file_one)
nh_df
# Out:
#        Unnamed: 0        id   host_id neighbourhood_group       neighbourhood  \
# 0               0      2539      2787            Brooklyn          Kensington
# 1               1      2595      2845           Manhattan             Midtown
# 2               2      3647      4632           Manhattan              Harlem
# 3               3      3831      4869            Brooklyn        Clinton Hill
# 4               4      5022      7192           Manhattan         East Harlem
# ...           ...       ...       ...                 ...                 ...
# 48890       48890  36484665   8232441            Brooklyn  Bedford-Stuyvesant
# 48891       48891  36485057   6570630            Brooklyn            Bushwick
# 48892       48892  36485431  23492952           Manhattan              Harlem
# 48893       48893  36485609  30985759           Manhattan      Hell's Kitchen
# 48894       48894  36487245  68119814           Manhattan      Hell's Kitchen
#
# ...

# %%
# Generate a pie plot showing the distribution of neighbourhoods by bourough
# groups=pd.DataFrame(nh_df.groupby(['neighbourhood']).count())

# %%
counts = nh_df ["neighbourhood"].value_counts()
counts.head(25)
# Out:
# Williamsburg                 3920
# Bedford-Stuyvesant           3714
# Harlem                       2658
# Bushwick                     2465
# Upper West Side              1971
# Hell's Kitchen               1958
# East Village                 1853
# Upper East Side              1798
# Crown Heights                1564
# Midtown                      1545
# East Harlem                  1117
# Greenpoint                   1115
# Chelsea                      1113
# Lower East Side               911
# Astoria                       900
# Washington Heights            899
# West Village                  768
# Financial District            744
# Flatbush                      621
# Clinton Hill                  572
# Long Island City              537
# Prospect-Lefferts Gardens     535
# Park Slope                    506
# East Flatbush                 500
# Fort Greene                   489
# Name: neighbourhood, dtype: int64

# %%
counts = nh_df["reviews_per_month"].value_counts()
counts.sort_values(ascending = False)
# Out:
# 0.00     10052
# 0.02       919
# 1.00       893
# 0.05       893
# 0.03       804
#          ...
# 11.68        1
# 9.50         1
# 10.72        1
# 27.95        1
# 7.99         1
# Name: reviews_per_month, Length: 938, dtype: int64

# %%
rpm = nh_df.sort_values(by=["reviews_per_month"])
rpm
# Out:
#        Unnamed: 0        id    host_id neighbourhood_group  \
# 48894       48894  36487245   68119814           Manhattan
# 8697         8697   6678351    7577024           Manhattan
# 28828       28828  22250584   53693534            Brooklyn
# 8702         8702   6685873    1030526            Brooklyn
# 28822       28822  22249641   22902111           Manhattan
# ...           ...       ...        ...                 ...
# 28651       28651  22176831  156684502              Queens
# 27287       27287  21550302  156684502              Queens
# 38870       38870  30423106  228415932              Queens
# 42076       42076  32678720  244361589           Manhattan
# 42075       42075  32678719  244361589           Manhattan
#
#              neighbourhood  latitude  longitude        room_type  price  \
# 48894       Hell's Kitchen  40.76404  -73.98933     Private room     90
# 8697                Harlem  40.82875  -73.94574     Private room    100
# ...

# %%
manhattan_nh = nh_df.loc[(nh_df["neighbourhood_group"]=="Manhattan")]
manhattan_nh
# Out:
#        Unnamed: 0        id    host_id neighbourhood_group   neighbourhood  \
# 1               1      2595       2845           Manhattan         Midtown
# 2               2      3647       4632           Manhattan          Harlem
# 4               4      5022       7192           Manhattan     East Harlem
# 5               5      5099       7322           Manhattan     Murray Hill
# 7               7      5178       8967           Manhattan  Hell's Kitchen
# ...           ...       ...        ...                 ...             ...
# 48886       48886  36483010  274311461           Manhattan         Midtown
# 48888       48888  36484087  274321313           Manhattan  Hell's Kitchen
# 48892       48892  36485431   23492952           Manhattan          Harlem
# 48893       48893  36485609   30985759           Manhattan  Hell's Kitchen
# 48894       48894  36487245   68119814           Manhattan  Hell's Kitchen
#
# ...

# %%
Mgroup=manhattan_nh.groupby("neighbourhood")["number_of_reviews"].sum()
Mgroup.sort_values(ascending = False)
# Out:
# neighbourhood
# Harlem                 75962
# Hell's Kitchen         50227
# East Village           44670
# East Harlem            36446
# Upper West Side        36058
# Upper East Side        31686
# Lower East Side        24161
# Chelsea                23641
# Midtown                19444
# Washington Heights     17161
# West Village           14885
# Chinatown               9941
# Gramercy                7682
# SoHo                    7235
# Financial District      6931
# Greenwich Village       6526
# Kips Bay                5837
# Nolita                  5634
# Inwood                  4690
# Morningside Heights     4599
# Murray Hill             4535
# Theater District        4342
# Little Italy            2799
# Two Bridges             2129
# Tribeca                 2034
# Flatiron District       1419
# Roosevelt Island        1214
# NoHo                     994
# Civic Center             637
# Battery Park City        580
# Stuyvesant Town          302
# ...
