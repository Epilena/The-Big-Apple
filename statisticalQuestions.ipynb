# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import gmaps
import requests
import time

# %%
#assign csv to variable
file_one = "AB_NYC_2019_clean.csv"

# %%
# !pip scipy
# Out:
# ERROR: unknown command "scipy"

# %%
#Read in csv file
stat_ques = pd.read_csv(file_one, index_col=0)
stat_ques.head()
# Out:
#      id  host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0  2539     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1  2595     2845           Manhattan       Midtown  40.75362  -73.98377
# 2  3647     4632           Manhattan        Harlem  40.80902  -73.94190
# 3  3831     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4  5022     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %%
#create manhattan df
manhattan = stat_ques.loc[(stat_ques["neighbourhood_group"]=="Manhattan")]
manhattan.head()
# Out:
#      id  host_id neighbourhood_group   neighbourhood  latitude  longitude  \
# 1  2595     2845           Manhattan         Midtown  40.75362  -73.98377
# 2  3647     4632           Manhattan          Harlem  40.80902  -73.94190
# 4  5022     7192           Manhattan     East Harlem  40.79851  -73.94399
# 5  5099     7322           Manhattan     Murray Hill  40.74767  -73.97500
# 7  5178     8967           Manhattan  Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 4  Entire home/apt     80              10                  9
# 5  Entire home/apt    200               3                 74
# 7     Private room     79               2                430
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 1               0.38                               2               355
# ...

# %%
manhattan.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.166100e+04  2.166100e+04  21661.000000  21661.000000  21661.000000
# mean   1.877494e+07  6.783062e+07     40.765062    -73.974607    196.875814
# std    1.116793e+07  7.936435e+07      0.038463      0.022138    291.383183
# min    2.595000e+03  2.845000e+03     40.702340    -74.018510      0.000000
# 25%    9.162161e+06  8.525424e+06     40.731820    -73.991690     95.000000
# 50%    1.911684e+07  3.065628e+07     40.760880    -73.980420    150.000000
# 75%    2.954121e+07  1.069498e+08     40.795090    -73.953840    220.000000
# max    3.648724e+07  2.743213e+08     40.876650    -73.908550  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    21661.000000       21661.000000       21661.000000
# mean         8.579151          20.985596           0.976782
# std         24.050857          42.572277           1.524518
# ...

# %%
#creat brooklyn df
brooklyn = stat_ques.loc[(stat_ques["neighbourhood_group"]== "Brooklyn")]
brooklyn.head()
# Out:
#       id  host_id neighbourhood_group       neighbourhood  latitude  \
# 0   2539     2787            Brooklyn          Kensington  40.64749
# 3   3831     4869            Brooklyn        Clinton Hill  40.68514
# 6   5121     7356            Brooklyn  Bedford-Stuyvesant  40.68688
# 12  5803     9744            Brooklyn         South Slope  40.66829
# 15  6848    15991            Brooklyn        Williamsburg  40.70837
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0   -73.97237     Private room    149               1                  9
# 3   -73.95976  Entire home/apt     89               1                270
# 6   -73.95596     Private room     60              45                 49
# 12  -73.98779     Private room     89               4                167
# 15  -73.95352  Entire home/apt    140               2                148
#
#     reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %%
brooklyn.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.010400e+04  2.010400e+04  20104.000000  20104.000000  20104.000000
# mean   1.825685e+07  5.671526e+07     40.685036    -73.951190    124.383207
# std    1.083320e+07  7.260060e+07      0.027397      0.025482    186.873538
# min    2.539000e+03  2.438000e+03     40.571150    -74.039420      0.000000
# 25%    8.704324e+06  5.611572e+06     40.672590    -73.963500     60.000000
# 50%    1.887604e+07  2.291993e+07     40.687520    -73.951740     90.000000
# 75%    2.784395e+07  7.910929e+07     40.704963    -73.935908    150.000000
# max    3.648506e+07  2.743076e+08     40.738900    -73.856760  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20104.000000       20104.000000       20104.000000
# mean         6.056556          24.202845           1.049790
# std         17.632726          44.344868           1.458036
# ...

# %%
#df - only manhattan and brooklyn
sample = manhattan.append(brooklyn)
sample
# Out:
#              id    host_id neighbourhood_group       neighbourhood  latitude  \
# 1          2595       2845           Manhattan             Midtown  40.75362
# 2          3647       4632           Manhattan              Harlem  40.80902
# 4          5022       7192           Manhattan         East Harlem  40.79851
# 5          5099       7322           Manhattan         Murray Hill  40.74767
# 7          5178       8967           Manhattan      Hell's Kitchen  40.76489
# ...         ...        ...                 ...                 ...       ...
# 48882  36482231   66058896            Brooklyn            Bushwick  40.69652
# 48884  36482783  274307600            Brooklyn        Williamsburg  40.71790
# 48887  36483152  208514239            Brooklyn        Williamsburg  40.71232
# 48890  36484665    8232441            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891  36485057    6570630            Brooklyn            Bushwick  40.70184
#
# ...

# %%
## WHICH WOULD BE BETTER RENTAL INCOME, A PROPERTY IN MANHATTAN OR BROOKLYN?""##

#Using the dataframe that combines Manhattan and Brooklyn
## Plan is to to do a # Independent t-test:
# also known as two sample t-test , determines whether there is a statistically significant
# difference between the means in two unrelated groups. 

# Should minimum stay be taken into account in the sampling?

# %%
#40,000 lines is a sample size of 380, or 190 samples each
sample.shape
# Out:
# (41765, 13)

# %%
# #create a sample set of 200 properties each in Manhattan and Brooklyn
sample200 = sample.groupby(["neighbourhood_group"]).sample(n=200)

sample200
# Out:
#              id    host_id neighbourhood_group       neighbourhood  latitude  \
# 31220  24246595   34360053            Brooklyn  Bedford-Stuyvesant  40.68790
# 2331    1130855    4623093            Brooklyn    Prospect Heights  40.67673
# 32493  25470372   34669755            Brooklyn        Williamsburg  40.71198
# 12404   9562515     253057            Brooklyn         Fort Greene  40.68965
# 34935  27699052    8855004            Brooklyn  Bedford-Stuyvesant  40.68891
# ...         ...        ...                 ...                 ...       ...
# 44324  34176229   34782150           Manhattan      Hell's Kitchen  40.76691
# 23657  19133220   16413765           Manhattan     Upper East Side  40.78084
# 43964  33969898  256504089           Manhattan     Upper West Side  40.80337
# 12701   9733741    9408069           Manhattan     Lower East Side  40.72082
# 46929  35492191   71577601           Manhattan  Financial District  40.70595
#
# ...

# %%
sample200=sample200[["id","neighbourhood_group","price"]]
sample200.reset_index()
# Out:
#      index        id neighbourhood_group  price
# 0    31220  24246595            Brooklyn     99
# 1     2331   1130855            Brooklyn     90
# 2    32493  25470372            Brooklyn    250
# 3    12404   9562515            Brooklyn    220
# 4    34935  27699052            Brooklyn     65
# ..     ...       ...                 ...    ...
# 395  44324  34176229           Manhattan    200
# 396  23657  19133220           Manhattan     98
# 397  43964  33969898           Manhattan     69
# 398  12701   9733741           Manhattan    180
# 399  46929  35492191           Manhattan    250
#
# [400 rows x 4 columns]

# %%
#checking size of new df
sample200.shape
# Out:
# (400, 3)

# %%
sample200.groupby("neighbourhood_group").describe()
# Out:
#                         id                                                   \
#                      count          mean           std       min        25%
# neighbourhood_group
# Brooklyn             200.0  1.831434e+07  1.067652e+07  114123.0  9489778.0
# Manhattan            200.0  1.832918e+07  1.159388e+07   12318.0  7396068.0
#
#                                                           price           \
#                             50%          75%         max  count     mean
# neighbourhood_group
# Brooklyn             16490224.0  27751549.25  36479230.0  200.0  119.960
# Manhattan            19013444.5  28826529.25  36427098.0  200.0  196.235
#
#
#                             std   min    25%    50%    75%     max
# neighbourhood_group
# Brooklyn              85.799336  20.0   61.5   96.0  151.0   600.0
# Manhattan            232.872104  45.0  100.0  150.0  225.0  3000.0

# %%
stats.ttest_ind(sample200['price'][sample200['neighbourhood_group'] == 'manhattan'],
                sample200['price'][sample200['neighbourhood_group'] == 'brooklyn'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-aae0435448f8> in <module>
# ----> 1 stats.ttest_ind(sample200['price'][sample200['neighbourhood_group'] == 'manhattan'],
#       2                 sample200['price'][sample200['neighbourhood_group'] == 'brooklyn'])
#
# NameError: name 'stats' is not defined
