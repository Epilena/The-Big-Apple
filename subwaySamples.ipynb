# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats
import pandas as pd

# %%
#assign csv to variable
file_one = "AB_NYC_2019_clean.csv"

# %%
#Read in csv file
reg_theory = pd.read_csv(file_one)
reg_theory
# Out:
#              id   host_id neighbourhood_group       neighbourhood  latitude  \
# 0          2539      2787            Brooklyn          Kensington  40.64749
# 1          2595      2845           Manhattan             Midtown  40.75362
# 2          3647      4632           Manhattan              Harlem  40.80902
# 3          3831      4869            Brooklyn        Clinton Hill  40.68514
# 4          5022      7192           Manhattan         East Harlem  40.79851
# ...         ...       ...                 ...                 ...       ...
# 48890  36484665   8232441            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891  36485057   6570630            Brooklyn            Bushwick  40.70184
# 48892  36485431  23492952           Manhattan              Harlem  40.81475
# 48893  36485609  30985759           Manhattan      Hell's Kitchen  40.75751
# 48894  36487245  68119814           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
manhattan = reg_theory.loc[(reg_theory["neighbourhood_group"]=="Manhattan")].sample(n=3)
manhattan
# Out:
#              id   host_id neighbourhood_group neighbourhood  latitude  \
# 8796    6748933   1490702           Manhattan       Chelsea  40.74121
# 12274   9492750  15441931           Manhattan        Harlem  40.80965
# 35860  28464743  11320557           Manhattan     Chinatown  40.71624
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 8796   -74.00122  Entire home/apt    145               6                  2
# 12274  -73.94553  Entire home/apt    190               3                102
# 35860  -73.99995     Private room    100               2                 35
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 8796                0.04                               1                 0
# 12274               2.33                               1               281
# 35860               4.32                               1                 6

# %%
brooklyn = reg_theory.loc[(reg_theory["neighbourhood_group"]=="Brooklyn")].sample(n=3)
brooklyn
# Out:
#              id    host_id neighbourhood_group       neighbourhood  latitude  \
# 2331    1130855    4623093            Brooklyn    Prospect Heights  40.67673
# 27853  21824124  159091490            Brooklyn             Gowanus  40.67860
# 27413  21620322    5120169            Brooklyn  Bedford-Stuyvesant  40.68344
#
#        longitude     room_type  price  minimum_nights  number_of_reviews  \
# 2331   -73.96399  Private room     90              14                 79
# 27853  -73.98381  Private room    139               1                 82
# 27413  -73.95329  Private room     50               2                  2
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 2331                1.09                               1               336
# 27853               4.16                              17               355
# 27413               0.10                               2                 0

# %%
queens = reg_theory.loc[(reg_theory["neighbourhood_group"]=="Queens")].sample(n=3)
queens
# Out:
#              id   host_id neighbourhood_group     neighbourhood  latitude  \
# 11040   8525477  22420999              Queens     Richmond Hill  40.69474
# 42665  33119863  42540127              Queens           Bayside  40.77067
# 7686    5805232   3974808              Queens  Ditmars Steinway  40.77780
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 11040  -73.83038     Private room     55               1                  7
# 42665  -73.78278  Entire home/apt     55               2                 37
# 7686   -73.91440     Private room    150               1                  0
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 11040               0.15                               5               344
# 42665              10.37                               1                 6
# 7686                0.00                               1                 0

# %%
bronx = reg_theory.loc[(reg_theory["neighbourhood_group"]=="Bronx")].sample(n=3)
bronx
# Out:
#              id    host_id neighbourhood_group neighbourhood  latitude  \
# 32853  25885278  193497177               Bronx   Throgs Neck  40.82257
# 27749  21778446  129602851               Bronx    Pelham Bay  40.84607
# 34709  27526997     310670               Bronx   Eastchester  40.88017
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 32853  -73.83773  Entire home/apt    100               2                 23
# 27749  -73.83842  Entire home/apt     99               7                  1
# 34709  -73.83574  Entire home/apt    475               2                  0
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 32853               1.84                               1                89
# 27749               0.06                               2               349
# 34709               0.00                              13               359

# %%
statenIsland = reg_theory.loc[(reg_theory["neighbourhood_group"]=="Staten Island")].sample(n=3)
statenIsland
# Out:
#              id    host_id neighbourhood_group  neighbourhood  latitude  \
# 41805  32502180  244217480       Staten Island  Arden Heights  40.54857
# 41443  32239170  241924064       Staten Island    Shore Acres  40.60525
# 5387    3892700      46969       Staten Island        Clifton  40.62050
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 41805  -74.17628  Entire home/apt     83              30                  3
# 41443  -74.06745  Entire home/apt    300               1                  0
# 5387   -74.07451  Entire home/apt     70               2                242
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 41805               0.90                               1               316
# 41443               0.00                               1                87
# 5387                4.09                               1               256

# %%
frames = [manhattan, brooklyn, queens, bronx, statenIsland]
test_sample = pd.concat(frames)
test_sample
# Out:
#              id    host_id neighbourhood_group       neighbourhood  latitude  \
# 8796    6748933    1490702           Manhattan             Chelsea  40.74121
# 12274   9492750   15441931           Manhattan              Harlem  40.80965
# 35860  28464743   11320557           Manhattan           Chinatown  40.71624
# 2331    1130855    4623093            Brooklyn    Prospect Heights  40.67673
# 27853  21824124  159091490            Brooklyn             Gowanus  40.67860
# 27413  21620322    5120169            Brooklyn  Bedford-Stuyvesant  40.68344
# 11040   8525477   22420999              Queens       Richmond Hill  40.69474
# 42665  33119863   42540127              Queens             Bayside  40.77067
# 7686    5805232    3974808              Queens    Ditmars Steinway  40.77780
# 32853  25885278  193497177               Bronx         Throgs Neck  40.82257
# 27749  21778446  129602851               Bronx          Pelham Bay  40.84607
# ...

# %%
test_sample.reset_index(drop=True)
test_sample
# Out:
#              id    host_id neighbourhood_group       neighbourhood  latitude  \
# 8796    6748933    1490702           Manhattan             Chelsea  40.74121
# 12274   9492750   15441931           Manhattan              Harlem  40.80965
# 35860  28464743   11320557           Manhattan           Chinatown  40.71624
# 2331    1130855    4623093            Brooklyn    Prospect Heights  40.67673
# 27853  21824124  159091490            Brooklyn             Gowanus  40.67860
# 27413  21620322    5120169            Brooklyn  Bedford-Stuyvesant  40.68344
# 11040   8525477   22420999              Queens       Richmond Hill  40.69474
# 42665  33119863   42540127              Queens             Bayside  40.77067
# 7686    5805232    3974808              Queens    Ditmars Steinway  40.77780
# 32853  25885278  193497177               Bronx         Throgs Neck  40.82257
# 27749  21778446  129602851               Bronx          Pelham Bay  40.84607
# ...

# %%
#assign csv to variable
file_two = "testSample.csv"

# %%
#Read in csv file
subwayStops = pd.read_csv(file_two)
subwayStops
# Out:
#              id  distance_from_subway
# 0          2539              0.477918
# 1          2595              0.059020
# 2          3647              0.566173
# 3          3831              0.258098
# 4          5022              0.241207
# ...         ...                   ...
# 48890  36484665              0.134009
# 48891  36485057              0.297540
# 48892  36485431              0.223452
# 48893  36485609              0.073996
# 48894  36487245              0.394647
#
# [48895 rows x 2 columns]

# %%
fullSet = pd.merge(test_sample, subwayStops, on=["id"], how = "left", indicator=True)
fullSet
# Out:
#           id    host_id neighbourhood_group       neighbourhood  latitude  \
# 0    6748933    1490702           Manhattan             Chelsea  40.74121
# 1    9492750   15441931           Manhattan              Harlem  40.80965
# 2   28464743   11320557           Manhattan           Chinatown  40.71624
# 3    1130855    4623093            Brooklyn    Prospect Heights  40.67673
# 4   21824124  159091490            Brooklyn             Gowanus  40.67860
# 5   21620322    5120169            Brooklyn  Bedford-Stuyvesant  40.68344
# 6    8525477   22420999              Queens       Richmond Hill  40.69474
# 7   33119863   42540127              Queens             Bayside  40.77067
# 8    5805232    3974808              Queens    Ditmars Steinway  40.77780
# 9   25885278  193497177               Bronx         Throgs Neck  40.82257
# 10  21778446  129602851               Bronx          Pelham Bay  40.84607
# 11  27526997     310670               Bronx         Eastchester  40.88017
# ...

# %%
fullSet["expected_price"] = fullSet.distance_from_subway*(-24.447) + 160.42
fullSet
# Out:
#           id    host_id neighbourhood_group       neighbourhood  latitude  \
# 0    6748933    1490702           Manhattan             Chelsea  40.74121
# 1    9492750   15441931           Manhattan              Harlem  40.80965
# 2   28464743   11320557           Manhattan           Chinatown  40.71624
# 3    1130855    4623093            Brooklyn    Prospect Heights  40.67673
# 4   21824124  159091490            Brooklyn             Gowanus  40.67860
# 5   21620322    5120169            Brooklyn  Bedford-Stuyvesant  40.68344
# 6    8525477   22420999              Queens       Richmond Hill  40.69474
# 7   33119863   42540127              Queens             Bayside  40.77067
# 8    5805232    3974808              Queens    Ditmars Steinway  40.77780
# 9   25885278  193497177               Bronx         Throgs Neck  40.82257
# 10  21778446  129602851               Bronx          Pelham Bay  40.84607
# 11  27526997     310670               Bronx         Eastchester  40.88017
# ...

# %%
#fullSet = fullSet.drop("host_id", 1)
fullSet = fullSet.drop("_merge",1)
fullSet
# Out:
#           id neighbourhood_group       neighbourhood  latitude  longitude  \
# 0    6748933           Manhattan             Chelsea  40.74121  -74.00122
# 1    9492750           Manhattan              Harlem  40.80965  -73.94553
# 2   28464743           Manhattan           Chinatown  40.71624  -73.99995
# 3    1130855            Brooklyn    Prospect Heights  40.67673  -73.96399
# 4   21824124            Brooklyn             Gowanus  40.67860  -73.98381
# 5   21620322            Brooklyn  Bedford-Stuyvesant  40.68344  -73.95329
# 6    8525477              Queens       Richmond Hill  40.69474  -73.83038
# 7   33119863              Queens             Bayside  40.77067  -73.78278
# 8    5805232              Queens    Ditmars Steinway  40.77780  -73.91440
# 9   25885278               Bronx         Throgs Neck  40.82257  -73.83773
# 10  21778446               Bronx          Pelham Bay  40.84607  -73.83842
# 11  27526997               Bronx         Eastchester  40.88017  -73.83574
# ...
