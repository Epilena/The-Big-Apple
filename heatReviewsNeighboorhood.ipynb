# %% [markdown]
# # AirBNB - Borough Heatmaps

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import gmaps
import requests
import time



#from config import (census_key, gkey)
# Import API key

# Output File (CSV)

#Range of latitudes and longitudes
#lat_range = (40.49979, 40.91306)
#lng_range = (-74.24442, -73.71299)
lat_range = (90, 180)
lng_range = (90, 180)

# %%
#assign csv to variable
file_one = "AB_NYC_2019_clean.csv"

# %%
#Read in csv file
abnb_data = pd.read_csv(file_one, index_col=0)
abnb_data.head()
# Out:
#       host_id neighbourhood_group neighbourhood  latitude  longitude  \
# id
# 2539     2787            Brooklyn    Kensington  40.64749  -73.97237
# 2595     2845           Manhattan       Midtown  40.75362  -73.98377
# 3647     4632           Manhattan        Harlem  40.80902  -73.94190
# 3831     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 5022     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#             room_type  price  minimum_nights  number_of_reviews  \
# id
# 2539     Private room    149               1                  9
# 2595  Entire home/apt    225               1                 45
# 3647     Private room    150               3                  0
# 3831  Entire home/apt     89               1                270
# 5022  Entire home/apt     80              10                  9
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# id
# 2539               0.21                               6               365
# ...

# %%
#create brooklyn dataframe
brooklyn = abnb_data.groupby("neighbourhood_group")
brooklyn = brooklyn.get_group('Brooklyn')
brooklyn.head()
# Out:
#       host_id neighbourhood_group       neighbourhood  latitude  longitude  \
# id
# 2539     2787            Brooklyn          Kensington  40.64749  -73.97237
# 3831     4869            Brooklyn        Clinton Hill  40.68514  -73.95976
# 5121     7356            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 5803     9744            Brooklyn         South Slope  40.66829  -73.98779
# 6848    15991            Brooklyn        Williamsburg  40.70837  -73.95352
#
#             room_type  price  minimum_nights  number_of_reviews  \
# id
# 2539     Private room    149               1                  9
# 3831  Entire home/apt     89               1                270
# 5121     Private room     60              45                 49
# 5803     Private room     89               4                167
# 6848  Entire home/apt    140               2                148
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# id
# ...

# %%
#create manhattan dataframe
manhattan = abnb_data.loc[(abnb_data["neighbourhood_group"]=="Manhattan")]
manhattan.head()
# Out:
#       host_id neighbourhood_group   neighbourhood  latitude  longitude  \
# id
# 2595     2845           Manhattan         Midtown  40.75362  -73.98377
# 3647     4632           Manhattan          Harlem  40.80902  -73.94190
# 5022     7192           Manhattan     East Harlem  40.79851  -73.94399
# 5099     7322           Manhattan     Murray Hill  40.74767  -73.97500
# 5178     8967           Manhattan  Hell's Kitchen  40.76489  -73.98493
#
#             room_type  price  minimum_nights  number_of_reviews  \
# id
# 2595  Entire home/apt    225               1                 45
# 3647     Private room    150               3                  0
# 5022  Entire home/apt     80              10                  9
# 5099  Entire home/apt    200               3                 74
# 5178     Private room     79               2                430
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# id
# ...

# %%
#create queens dataframe
queens = abnb_data.loc[(abnb_data["neighbourhood_group"]=="Queens")]
queens.head()
# Out:
#        host_id neighbourhood_group     neighbourhood  latitude  longitude  \
# id
# 12937    50124              Queens  Long Island City  40.74771  -73.94740
# 18198    70091              Queens          Woodside  40.75038  -73.90334
# 32363   140025              Queens          Flushing  40.74028  -73.83168
# 39593   110506              Queens         Sunnyside  40.74559  -73.92313
# 45910   204539              Queens         Ridgewood  40.70382  -73.89797
#
#              room_type  price  minimum_nights  number_of_reviews  \
# id
# 12937     Private room    130               3                248
# 18198     Private room     70              30                 25
# 32363     Private room    140               2                  1
# 39593     Private room     79              30                 28
# 45910  Entire home/apt    350               8                 10
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# id
# ...

# %%
#create bronxdataframe
bronx = abnb_data.loc[(abnb_data["neighbourhood_group"]=="Bronx")]
bronx.head()
# Out:
#        host_id neighbourhood_group neighbourhood  latitude  longitude  \
# id
# 44096   190409               Bronx    Highbridge  40.83232  -73.93184
# 54626   190409               Bronx    Highbridge  40.83075  -73.93058
# 63588   295128               Bronx  Clason Point  40.81309  -73.85514
# 63610   310670               Bronx   Eastchester  40.88057  -73.83572
# 71812   369015               Bronx   Kingsbridge  40.87207  -73.90193
#
#              room_type  price  minimum_nights  number_of_reviews  \
# id
# 44096     Private room     40               1                219
# 54626     Private room     45               1                138
# 63588     Private room     90               2                  0
# 63610  Entire home/apt    105               2                 38
# 71812  Entire home/apt     90              30                  4
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# id
# ...

# %%
#create staten island dataframe
staten = abnb_data.loc[(abnb_data["neighbourhood_group"]=="Staten Island")]
staten.head()
# Out:
#        host_id neighbourhood_group  neighbourhood  latitude  longitude  \
# id
# 42882   185978       Staten Island     St. George  40.64524  -74.08088
# 62452   303939       Staten Island  Tompkinsville  40.63536  -74.08537
# 62461   303939       Staten Island  Tompkinsville  40.63627  -74.08543
# 62787   303939       Staten Island  Tompkinsville  40.63518  -74.08546
# 63320   303939       Staten Island  Tompkinsville  40.63481  -74.08519
#
#           room_type  price  minimum_nights  number_of_reviews  \
# id
# 42882  Private room     70               2                166
# 62452  Private room     36               2                193
# 62461  Private room     37               2                147
# 62787  Private room     37               2                177
# 63320  Private room     36               2                333
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# id
# ...

# %%
#Store latitude and longitude into locations
locations_b = brooklyn[["latitude","longitude"]].astype(float)
locations_m = manhattan[["latitude","longitude"]].astype(float)
locations_q = queens[["latitude","longitude"]].astype(float)
locations_bx = bronx[["latitude","longitude"]].astype(float)
locations_si = staten[["latitude","longitude"]].astype(float)

# %%
#Heatmap for manhattan reviews
fig1 = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations_m, weights= manhattan.number_of_reviews,
                                 dissipating=False, max_intensity=100, point_radius=.001)
fig1.add_layer(heat_layer)
fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Heatmap for Brooklyn reviews
fig2 = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations_b, weights= brooklyn.number_of_reviews,
                                 dissipating=False, max_intensity=100, point_radius=.001)
fig2.add_layer(heat_layer)
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Heatmap for Queens reviews
fig3 = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations_q, weights= queens.number_of_reviews,
                                 dissipating=False, max_intensity=100, point_radius=.001)
fig3.add_layer(heat_layer)
fig3
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Heatmap for Bronx reviews
fig4 = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations_bx, weights= bronx.number_of_reviews,
                                 dissipating=False, max_intensity=100, point_radius=.001)
fig4.add_layer(heat_layer)
fig4
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Heatmap for Staten Island reviews
fig5 = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations_si, weights= staten.number_of_reviews,
                                 dissipating=False, max_intensity=100, point_radius=.001)
fig5.add_layer(heat_layer)
fig5
# Out:
# Figure(layout=FigureLayout(height='420px'))
